# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab

# %%
t = np.linspace(0, 1, 1000)
y = np.sin(35e3 * t)

# %%
sample_freq = 100e3
sample_inter = 1 / sample_freq
samples = 1000
time = np.linspace(0, samples * sample_inter, samples)

# %%
signal_freq = 35e3
signal = np.sin(2*np.pi*signal_freq * time)

signal_spect = np.fft.fftshift(np.fft.fft(signal))
freqs = np.fft.fftshift(np.fft.fftfreq(samples, d=sample_inter))

# %%
N = len(y)
parseval_1 = np.sum(signal ** 2)
parseval_2 = np.sum(np.abs(signal_spect ** 2)) / N
print(parseval_1)
print(parseval_2)
# Out:
# 499.5
# 499.5

# %%
fig = plt.figure(figsize=(25,5))

axes1 = fig.add_subplot(1, 3, 1)
axes2 = fig.add_subplot(1, 3, 2)
axes3 = fig.add_subplot(1, 3, 3)

axes1.plot(t, y)
axes1.set_xlabel('Time (s)');
axes1.set_ylabel('Amplitude');

axes2.plot(freqs / 1e3, np.abs(signal_spect) / samples)
axes2.set_xlabel('Frequency (khz)');
axes2.set_ylabel('Power');

axes3.specgram(signal, NFFT=256,noverlap=0,Fs = 100e3, window=mlab.window_none)
axes3.set_xlabel('Time (s)');
axes3.set_ylabel('Frequency (hz)');

# %%
plt.show()
